# %%
import os
import sys

# Because the notebook is inside 'notebook/raw/', we need to go up TWO levels
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

import numpy as np
import pandas as pd
import pickle
from tensorflow.keras.models import load_model

# Now python will scale up to internship_project1 seamlessly!
from src.metrics import calculate_evaluation_metrics, generate_confusion_matrix_plot
from src.config import BASE_DIR, RAW_DATA_PATH

# Setting up dynamic path locations based on your BASE_DIR
MODELS_DIR = os.path.join(BASE_DIR, "models")
print(f"✅ System environment mapped. Models directory targeting: {MODELS_DIR}")
# Out:
# ✅ System environment mapped. Models directory targeting: c:\Users\ANAMIKA\OneDrive\Desktop\internship_project1\models
